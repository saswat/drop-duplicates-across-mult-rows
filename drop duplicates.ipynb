# %%
import pandas as pd
import numpy as np
import os
print(os.getcwd())
# Out:
# C:\Users\SSP\Documents\pyscripts

# %%
df = pd.read_excel("dummydata.xlsx")

# %%
df
# Out:
#     ID characteristic  other_identifier
# 0    1            red               593
# 1    1           blue               604
# 2    1          green               721
# 3    1         violet               798
# 4    1         orange               156
# 5    2            red               148
# 6    2            red               520
# 7    2           blue                81
# 8    2          black               966
# 9    2          green               512
# 10   2         orange               357
# 11   3            red               959
# 12   3           blue               128
# 13   3          green               339
# 14   3          green               726
# 15   4         orange               862
# 16   4            red               251
# 17   4            red               747
# 18   4          black               906
# 19   5           blue               347
# 20   5            red               543
# 21   6            red               895
# ...

# %%
df.shape
# Out:
# (29, 3)

# %%
df2 = df.drop_duplicates(["ID", "characteristic"])

# %%
df2
# Out:
#     ID characteristic  other_identifier
# 0    1            red               593
# 1    1           blue               604
# 2    1          green               721
# 3    1         violet               798
# 4    1         orange               156
# 5    2            red               148
# 7    2           blue                81
# 8    2          black               966
# 9    2          green               512
# 10   2         orange               357
# 11   3            red               959
# 12   3           blue               128
# 13   3          green               339
# 15   4         orange               862
# 16   4            red               251
# 18   4          black               906
# 19   5           blue               347
# 20   5            red               543
# 21   6            red               895
# 22   6           blue               209
# 23   6          green                84
# 24   6         violet               580
# ...

# %%
df2.shape
# Out:
# (25, 3)

# %%
df3 = df2.groupby('ID').characteristic.size()

# %%
df3
# Out:
# ID
# 1    5
# 2    5
# 3    3
# 4    3
# 5    2
# 6    7
# Name: characteristic, dtype: int64
